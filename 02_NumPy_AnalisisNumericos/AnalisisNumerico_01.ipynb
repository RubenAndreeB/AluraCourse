# %% [markdown]
# <a href="https://colab.research.google.com/github/RubenAndreeB/AluraCourse/blob/main/02_NumPy_AnalisisNumericos/AnalisisNumerico_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy: Análisis numérico eficiente con Python

# %% [markdown]
# NumPy es una biblioteca de Python que ofrece diversas herramientas y funcionalidades esenciales para la computación científica, incluyendo objetos de matriz multidimensional conocidos como arrays, rutinas para operaciones rápidas en matrizes, además de operaciones matemáticas, manipulación de formas, estadística entre otros. Es ampliamente utilizada en áreas como análisis de datos, procesamiento de señales y aprendizaje de máquina.
#
# Para acceder a la documentación de esta biblioteca, puedes hacer clic en el siguiente enlace: https://numpy.org/devdocs/index.html

# %% [markdown]
# ## Importando las bibliotecas y conectando con Drive

# %%
import numpy as np

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/41b8a65c5e5b58125401deafb68af460/raw/f84320f69efa1cc3e86e1db054422cfa4869c63e/manzanas.csv'

datos = np.loadtxt(url, delimiter=',', usecols=np.arange(1,88,1))

# %%
##### Metodo para hacerlo desde drive #####
# from google.colab import drive

# drive.mount('/content/drive')
# path = '/content/drive/MyDrive/Numpy/manzanas.csv'

# %%
datos.ndim
# Out:
# 2

# %%
datos.shape
# Out:
# (6, 87)

# %%
datos_transpuestos = datos.T

# %% [markdown]
# ## Exploracion de Datos

# %% [markdown]
# ### Visualización y Selección

# %%
fechas = datos_transpuestos[:,0]
fechas
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
precios = datos_transpuestos[:,1:]
precios
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,  66.06,  61.27,  72.91],
#        [ 80.8 ,  51.59,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
#        [ 76.05,  63.21,  75.16,  53.81,  81.2 ],
#        [ 75.53,  61.2 ,  74.86,  55.5 ,  82.04],
#        [ 73.39,  60.34,  71.47,  52.95,  79.67],
#        [ 78.36,  62.2 ,  76.08,  53.29,  81.25],
#        [ 89.16,  74.2 ,  82.11,  54.86,  85.88],
#        [105.43,  75.32,  94.63,  71.72,  91.35],
#        [104.82,  75.92,  98.54,  74.36, 101.32],
#        [101.15,  72.89,  97.84,  78.25, 102.45],
#        [ 98.63,  74.85,  94.54,  70.63,  98.18],
#        [ 99.96,  92.19,  97.88,  77.06, 105.1 ],
#        [ 97.29,  99.7 ,  97.73,  81.52, 104.85],
#        [ 98.64, 102.78, 100.89,  84.12, 111.48],
#        [104.26,  92.67, 104.88,  83.33, 118.51],
#        [102.63,  90.63, 104.39,  66.98, 118.92],
#        [ 98.64,  83.31, 101.9 ,  62.04, 109.87],
#        [ 97.17,  75.5 ,  98.99,  59.79, 105.22],
#        [ 98.09,  74.6 ,  99.42,  66.06, 105.45],
#        [103.07,  76.94, 106.37,  71.99, 115.61],
#        [110.26,  83.04, 113.89,  76.79, 116.61],
#        [110.84,  80.74, 114.78,  80.98, 120.39],
#        [112.28,  80.29, 115.6 ,  89.18, 119.2 ],
#        [111.1 ,  82.82, 115.89,  92.71, 119.92],
#        [110.06,  86.29, 117.66,  94.85, 120.57],
#        [113.7 ,  87.41, 118.27,  99.18, 123.37],
#        [112.88,  85.1 , 114.19,  86.33, 121.39],
#        [102.08,  78.08, 101.81,  71.94, 118.16],
#        [ 95.54,  76.06,  91.62,  67.18, 108.84],
#        [ 91.33,  69.23,  90.15,  62.98, 100.78],
#        [ 89.99,  69.04,  90.55,  69.45,  99.92],
#        [ 91.44,  64.48,  92.3 ,  67.56, 100.65],
#        [ 93.51,  65.73,  91.75,  67.92,  98.92],
#        [ 93.6 ,  67.2 ,  92.  ,  68.4 , 100.31],
#        [ 93.78,  70.25,  92.57,  67.97,  96.41],
#        [ 98.91,  82.59, 100.28,  76.33, 101.24],
#        [121.76,  92.12, 114.33,  95.79, 118.7 ],
#        [129.6 , 100.82, 122.17, 112.36, 133.29],
#        [127.9 ,  95.23, 117.83,  82.03, 130.31],
#        [114.55,  89.51, 112.49,  73.83, 122.4 ],
#        [101.88,  82.84,  93.7 ,  66.12, 104.98],
#        [ 99.09,  82.3 ,  97.17,  63.24, 107.54],
#        [103.35,  83.76,  95.64,  63.98, 110.74],
#        [106.58,  84.72, 102.21,  69.1 , 110.51],
#        [108.  ,  83.91, 107.58,  70.04, 111.46],
#        [114.95,  99.14, 110.48,  80.03, 113.42],
#        [121.17, 101.6 , 117.73,  87.92, 118.15],
#        [122.48, 113.03, 122.07,  97.07, 114.  ],
#        [127.58, 119.54, 128.58, 106.52, 124.91],
#        [131.89, 118.09, 131.12, 108.93, 126.06],
#        [129.36, 107.32, 127.08,  95.17, 123.3 ],
#        [104.26,  82.6 , 110.99,  74.31, 111.61],
#        [ 93.45,  77.4 ,  97.43,  62.63,  98.82],
#        [ 92.93,  71.77,  92.05,  69.92,  97.47],
#        [ 96.15,  71.25,  93.21,  70.58, 103.01],
#        [ 99.1 ,  71.35,  98.58,  74.63, 109.36],
#        [103.  ,  73.62, 100.23,  78.69, 104.79],
#        [103.31,  76.2 , 102.09,  81.82, 105.09],
#        [103.01,  74.15, 101.73,  82.36, 103.16],
#        [107.37,  75.67, 107.28,  89.44, 106.52],
#        [116.91,  79.2 , 115.35, 102.01, 121.68],
#        [125.29,  80.85, 123.03, 116.12, 125.32],
#        [123.94,  85.33, 123.08,  92.06, 123.41],
#        [113.03,  75.02, 109.71,  82.7 , 108.48],
#        [102.19,  77.95,  97.22,  66.62,  98.73],
#        [ 97.83,  78.98,  95.75,  68.11,  96.25],
#        [101.07,  76.55,  97.09,  73.48, 100.12],
#        [103.44,  74.89,  98.18,  82.04, 101.29],
#        [108.23,  70.  , 103.1 ,  81.19, 102.81],
#        [110.28,  81.53, 110.6 ,  95.05, 108.53]])

# %%
import matplotlib.pyplot as plt\

plt.plot(fechas, precios)
plt.show()

# %%
# Grafica para solo Moscow
plt.plot(fechas, precios[:,0])
plt.show()

# %%
fechas = np.arange(1,88,1)

# %%
# Grafica para solo Moscu
plt.plot(fechas, precios[:,0])
plt.show()

# %%
Moscu = precios[:,0]
Kaliningrado = precios[:,1]
Petersburgo = precios[:,2]
Krasnodar = precios[:,3]
Ekaterimburgo = precios[:,4]

# %%
plt.plot(fechas, Kaliningrado)

# %% [markdown]
# ### Comparacion entre arrays

# %%
Moscu.shape
# Out:
# (87,)

# %%
Moscu_1 = Moscu[0:12]
Moscu_2 = Moscu[12:24]
Moscu_3 = Moscu[24:36]
Moscu_4 = Moscu[36:48]

# %%
plt.plot(np.arange(1,13,1), Moscu_1)
plt.plot(np.arange(1,13,1), Moscu_2)
plt.plot(np.arange(1,13,1), Moscu_3)
plt.plot(np.arange(1,13,1), Moscu_4)
plt.legend(['2013','2014','2015','2016'])
plt.show()

# %%
np.array_equal(Moscu_1, Moscu_2)
# Out:
# False

# %%
np.allclose(Moscu_1, Moscu_2, 1)
# Out:
# True

# %% [markdown]
# ### Tratamiento de Nan

# %%
np.mean(Moscu)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(Kaliningrado)
# Out:
# np.float64(nan)

# %%
plt.plot(fechas, Kaliningrado)

# %%
Kaliningrado
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
np.isnan(Kaliningrado)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
np.sum(np.isnan(Kaliningrado))
# Out:
# np.int64(1)

# %%
Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado [5])/2

# %%
plt.plot(fechas, Kaliningrado)

# %%
np.mean(Kaliningrado)
# Out:
# np.float64(74.5506896551724)

# %% [markdown]
# ## Operaciones entre arrays

# %% [markdown]
# ### Diferencias entre arrays

# %%
plt.plot(fechas, Moscu)

# %%
x = fechas
y = 1.5 * x + 78

# %%
y
# Out:
# array([ 79.5,  81. ,  82.5,  84. ,  85.5,  87. ,  88.5,  90. ,  91.5,
#         93. ,  94.5,  96. ,  97.5,  99. , 100.5, 102. , 103.5, 105. ,
#        106.5, 108. , 109.5, 111. , 112.5, 114. , 115.5, 117. , 118.5,
#        120. , 121.5, 123. , 124.5, 126. , 127.5, 129. , 130.5, 132. ,
#        133.5, 135. , 136.5, 138. , 139.5, 141. , 142.5, 144. , 145.5,
#        147. , 148.5, 150. , 151.5, 153. , 154.5, 156. , 157.5, 159. ,
#        160.5, 162. , 163.5, 165. , 166.5, 168. , 169.5, 171. , 172.5,
#        174. , 175.5, 177. , 178.5, 180. , 181.5, 183. , 184.5, 186. ,
#        187.5, 189. , 190.5, 192. , 193.5, 195. , 196.5, 198. , 199.5,
#        201. , 202.5, 204. , 205.5, 207. , 208.5])

# %%
plt.plot(x,y)
plt.plot(fechas, Moscu)

# %%
Moscu - y
# Out:
# array([ 2.2000e-01,  8.0000e-02, -2.8200e+00, -4.2000e+00, -4.8700e+00,
#        -6.2000e+00, -8.2200e+00, -1.1010e+01, -1.4730e+01, -1.6910e+01,
#        -1.8140e+01, -1.8840e+01, -2.0000e+01, -1.9970e+01, -2.0220e+01,
#        -2.1950e+01, -2.5390e+01, -2.8100e+01, -2.8820e+01, -3.1950e+01,
#        -3.3970e+01, -3.7610e+01, -3.4140e+01, -2.4840e+01, -1.0070e+01,
#        -1.2180e+01, -1.7350e+01, -2.1370e+01, -2.1540e+01, -2.5710e+01,
#        -2.5860e+01, -2.1740e+01, -2.4870e+01, -3.0360e+01, -3.3330e+01,
#        -3.3910e+01, -3.0430e+01, -2.4740e+01, -2.5660e+01, -2.5720e+01,
#        -2.8400e+01, -3.0940e+01, -2.8800e+01, -3.1120e+01, -4.3420e+01,
#        -5.1460e+01, -5.7170e+01, -6.0010e+01, -6.0060e+01, -5.9490e+01,
#        -6.0900e+01, -6.2220e+01, -5.8590e+01, -3.7240e+01, -3.0900e+01,
#        -3.4100e+01, -4.8950e+01, -6.3120e+01, -6.7410e+01, -6.4650e+01,
#        -6.2920e+01, -6.3000e+01, -5.7550e+01, -5.2830e+01, -5.3020e+01,
#        -4.9420e+01, -4.6610e+01, -5.0640e+01, -7.7240e+01, -8.9550e+01,
#        -9.1570e+01, -8.9850e+01, -8.8400e+01, -8.6000e+01, -8.7190e+01,
#        -8.8990e+01, -8.6130e+01, -7.8090e+01, -7.1210e+01, -7.4060e+01,
#        -8.6470e+01, -9.8810e+01, -1.0467e+02, -1.0293e+02, -1.0206e+02,
#        -9.8770e+01, -9.8220e+01])

# %%
np.sqrt(np.sum(np.power(Moscu - y,2)))
# Out:
# np.float64(500.33320307571034)

# %%
x = fechas
y = 0.5 * x + 78

# %%
plt.plot(x,y)
plt.plot(fechas, Moscu)

# %%
np.sqrt(np.sum(np.power(Moscu - y,2)))
# Out:
# np.float64(103.53131941591394)

# %%
np.linalg.norm(Moscu - y)
# Out:
# np.float64(103.53131941591394)

# %% [markdown]
# ### Regresion lineal

# %% [markdown]
# $$ α = pendiente $$
# $$ β = interseccion $$
# $$ n = observaciones $$
# $$ y = precio $$
# $$ x = fecha $$
#
# La solucion para la pendiente es:
# $$ \alpha = \frac{n \sum xy - \sum x \sum y}{n \sum x^2 - (\sum x) ^2} $$
#
# Y para la intersección:
# $$ \beta = \frac{\sum y - \alpha \sum x}{n}$$
#
# Y obtenemos la ecuacion de la recta:
# $$ y = \alpha x + \beta $$

# %%
n = np.size(Moscu)
y = Moscu
x = fechas

# %% [markdown]
# $$ \alpha = \frac{n \sum xy - \sum x \sum y}{n \sum x^2 - (\sum x) ^2} $$

# %%
a = (n*np.sum(x*y)-np.sum(x)*np.sum(y))/(n*np.sum(x**2)-np.sum(x)**2)

# %% [markdown]
# $$ \beta = \frac{\sum y - \alpha \sum x}{n}$$

# %%
b = np.mean(y) - a * np.mean(x)

# %%
print(f'La pendiente es: {a} \nLa interseccion es: {b}')
# Out:
# La pendiente es: 0.43520212145512926
# La interseccion es: 79.64892274792834

# %%
y = a * x + b

# %%
y
# Out:
# array([ 80.08412487,  80.51932699,  80.95452911,  81.38973123,
#         81.82493336,  82.26013548,  82.6953376 ,  83.13053972,
#         83.56574184,  84.00094396,  84.43614608,  84.87134821,
#         85.30655033,  85.74175245,  86.17695457,  86.61215669,
#         87.04735881,  87.48256093,  87.91776306,  88.35296518,
#         88.7881673 ,  89.22336942,  89.65857154,  90.09377366,
#         90.52897578,  90.96417791,  91.39938003,  91.83458215,
#         92.26978427,  92.70498639,  93.14018851,  93.57539063,
#         94.01059276,  94.44579488,  94.880997  ,  95.31619912,
#         95.75140124,  96.18660336,  96.62180548,  97.05700761,
#         97.49220973,  97.92741185,  98.36261397,  98.79781609,
#         99.23301821,  99.66822033, 100.10342246, 100.53862458,
#        100.9738267 , 101.40902882, 101.84423094, 102.27943306,
#        102.71463519, 103.14983731, 103.58503943, 104.02024155,
#        104.45544367, 104.89064579, 105.32584791, 105.76105004,
#        106.19625216, 106.63145428, 107.0666564 , 107.50185852,
#        107.93706064, 108.37226276, 108.80746489, 109.24266701,
#        109.67786913, 110.11307125, 110.54827337, 110.98347549,
#        111.41867761, 111.85387974, 112.28908186, 112.72428398,
#        113.1594861 , 113.59468822, 114.02989034, 114.46509246,
#        114.90029459, 115.33549671, 115.77069883, 116.20590095,
#        116.64110307, 117.07630519, 117.51150731])

# %%
np.linalg.norm(Moscu - y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(fechas, Moscu)
plt.plot(x,y)

# %% [markdown]
# ### Aplicando la regresion

# %%
plt.plot(fechas, Moscu)
plt.plot(x,y)
plt.plot(25,a*25+b, '*r')

# %%
a*25+b
# Out:
# np.float64(90.52897578430657)

# %% [markdown]
# ## Numeros Aleatorios

# %% [markdown]
# ### Generando numeros aleatorios

# %%
# Entero
np.random.randint(40, 100, 100)
# Out:
# array([93, 45, 53, 40, 94, 84, 94, 72, 48, 54, 73, 97, 63, 85, 44, 81, 70,
#        71, 69, 52, 52, 89, 44, 69, 44, 53, 44, 58, 93, 47, 90, 79, 57, 89,
#        73, 51, 54, 86, 55, 64, 53, 70, 47, 89, 63, 44, 74, 58, 65, 95, 55,
#        98, 42, 83, 92, 46, 59, 53, 99, 46, 48, 95, 83, 41, 98, 44, 75, 72,
#        90, 43, 57, 61, 81, 77, 68, 41, 79, 78, 45, 84, 67, 98, 50, 70, 40,
#        52, 40, 53, 47, 70, 74, 64, 41, 92, 88, 68, 73, 86, 97, 80])

# %%
# Decimal o flotantes
np.random.uniform(0.1, 0.9, 100)
# Out:
# array([0.49939079, 0.82837666, 0.26301688, 0.29130798, 0.23688392,
#        0.56149426, 0.46427363, 0.87431922, 0.69312111, 0.61275235,
#        0.88576334, 0.4434606 , 0.75859182, 0.82058577, 0.20512382,
#        0.77095375, 0.50488906, 0.70913769, 0.86969018, 0.27858916,
#        0.59627755, 0.78625479, 0.3670642 , 0.78525956, 0.59161046,
#        0.26376424, 0.29885914, 0.7243468 , 0.12138571, 0.66299982,
#        0.89330672, 0.22567778, 0.66447121, 0.28649217, 0.89798659,
#        0.38874486, 0.13965807, 0.25937222, 0.68305989, 0.87534921,
#        0.6669355 , 0.30704951, 0.76867255, 0.54591851, 0.54153061,
#        0.44184759, 0.52056526, 0.34345996, 0.49387611, 0.21501611,
#        0.50446355, 0.34808504, 0.5266065 , 0.61631592, 0.4877641 ,
#        0.15494809, 0.8222176 , 0.20756145, 0.19488522, 0.28807462,
#        0.29868098, 0.50571267, 0.83714384, 0.71303539, 0.77893014,
#        0.88342973, 0.51708627, 0.83437833, 0.51817801, 0.69701891,
#        0.2636271 , 0.38041339, 0.21491102, 0.16834526, 0.34669728,
#        0.41105102, 0.34190637, 0.75468285, 0.89021079, 0.27847662,
#        0.55461598, 0.52911162, 0.13861032, 0.74639396, 0.27610759,
#        0.85769798, 0.54877449, 0.42349052, 0.61044211, 0.35888649,
#        0.3314297 , 0.4619361 , 0.20461286, 0.75088734, 0.41509259,
#        0.39130461, 0.47038836, 0.65000681, 0.58062555, 0.78795403])

# %%
pendientes = np.random.uniform(0.1, 0.9, 100)

# %%
for i in range(100):
  print(np.linalg.norm(Moscu - (pendientes[i] * x + b)))
# Out:
# 107.49525395735934
# 105.52376007584623
# 131.1671380792139
# 130.02108164607247
# 107.96503357505254
# 103.46533020380747
# 178.8231038570966
# 114.25657880668908
# 168.67639689815323
# 102.36510190946959
# 103.19109837437324
# 211.06765125657228
# 112.17711637056388
# 133.9867516890709
# 129.64232316150841
# 189.08337539054034
# 191.1615774400552
# 104.65020759005107
# 163.85616866630406
# 105.87377902683414
# 236.57373244495705
# 159.72850337278007
# 151.52270996770068
# 164.35684010193683
# 122.35355939988868
# 125.23097542911444
# 175.27237015747906
# 110.10533709524978
# 111.85390682235311
# 181.21655747287784
# 103.05415187855225
# 101.88901498370173
# 210.70780655145396
# 126.21054776013605
# 111.88705757276146
# 181.9495392597482
# 101.79816667955484
# 111.47766540630323
# 189.6863590091787
# 117.4777961891899
# 238.74974218897924
# 178.7725268083018
# 178.67602877577775
# 103.18880278487948
# 160.3398020239651
# 188.26399566909114
# 103.52972942084948
# 157.92981338748598
# 155.8326809601092
# 128.23865304495135
# 172.48849667802833
# 206.51369385918244
# 116.47052838192946
# 233.3784809281227
# 146.44560369348895
# 156.87419122336942
# 111.56221054581319
# 127.18292297517506
# 104.81209170987601
# 122.98364519556154
# 116.28717982266213
# 105.115213364121
# 188.59346285613265
# 145.58328934366884
# 111.69442763925711
# 108.84991507402303
# 158.8437197715183
# 132.8369626002244
# 101.8127496186495
# 169.7388780664413
# 136.8746401387582
# 138.0339667956179
# 153.69038640540467
# 144.658540905439
# 168.79660695386838
# 184.1957479186469
# 180.21680438180942
# 160.09632515397473
# 129.80324765343127
# 101.85956409827806
# 103.09039880971388
# 167.2581988586415
# 134.00601101850236
# 224.9815541525293
# 102.16018782654751
# 145.15084281123157
# 183.16484881776137
# 161.4386087113226
# 180.93394016517806
# 175.9877873904082
# 231.9239669286495
# 107.04830951468968
# 194.2896397461056
# 151.49074953336498
# 101.84219164957015
# 111.16931811235457
# 128.75832843589131
# 177.56461332019296
# 153.27266597605842
# 112.93915562327052

# %%
norma = np.array([])
for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscu - (pendientes[i] * x + b)))

# %% [markdown]
# ### Reproductibilidad

# %%
np.random.seed(99)
np.random.uniform(0.1, 0.9, 5)
# Out:
# array([0.63782285, 0.49046272, 0.76039614, 0.12515711, 0.74643997])

# %%
np.random.seed(99)
np.random.uniform(0.1, 0.9, 5)
# Out:
# array([0.63782285, 0.49046272, 0.76039614, 0.12515711, 0.74643997])

# %%
np.random.seed(99)

norma = np.array([])

for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscu - (pendientes[i] * x + b)))

norma
# Out:
# array([107.49525396, 105.52376008, 131.16713808, 130.02108165,
#        107.96503358, 103.4653302 , 178.82310386, 114.25657881,
#        168.6763969 , 102.36510191, 103.19109837, 211.06765126,
#        112.17711637, 133.98675169, 129.64232316, 189.08337539,
#        191.16157744, 104.65020759, 163.85616867, 105.87377903,
#        236.57373244, 159.72850337, 151.52270997, 164.3568401 ,
#        122.3535594 , 125.23097543, 175.27237016, 110.1053371 ,
#        111.85390682, 181.21655747, 103.05415188, 101.88901498,
#        210.70780655, 126.21054776, 111.88705757, 181.94953926,
#        101.79816668, 111.47766541, 189.68635901, 117.47779619,
#        238.74974219, 178.77252681, 178.67602878, 103.18880278,
#        160.33980202, 188.26399567, 103.52972942, 157.92981339,
#        155.83268096, 128.23865304, 172.48849668, 206.51369386,
#        116.47052838, 233.37848093, 146.44560369, 156.87419122,
#        111.56221055, 127.18292298, 104.81209171, 122.9836452 ,
#        116.28717982, 105.11521336, 188.59346286, 145.58328934,
#        111.69442764, 108.84991507, 158.84371977, 132.8369626 ,
#        101.81274962, 169.73887807, 136.87464014, 138.0339668 ,
#        153.69038641, 144.65854091, 168.79660695, 184.19574792,
#        180.21680438, 160.09632515, 129.80324765, 101.8595641 ,
#        103.09039881, 167.25819886, 134.00601102, 224.98155415,
#        102.16018783, 145.15084281, 183.16484882, 161.43860871,
#        180.93394017, 175.98778739, 231.92396693, 107.04830951,
#        194.28963975, 151.49074953, 101.84219165, 111.16931811,
#        128.75832844, 177.56461332, 153.27266598, 112.93915562])

# %% [markdown]
# ### Exportacion

# %%
pendientes
# Out:
# array([0.50828318, 0.49402488, 0.26015561, 0.6063768 , 0.35908296,
#        0.39604081, 0.12407771, 0.5449987 , 0.71982133, 0.45799367,
#        0.3994276 , 0.82648038, 0.33546926, 0.25084002, 0.26531883,
#        0.77240103, 0.77760825, 0.48656274, 0.70691876, 0.49677711,
#        0.88712002, 0.69567961, 0.19769273, 0.70826958, 0.29155358,
#        0.28084784, 0.13326196, 0.34640851, 0.53329583, 0.75246779,
#        0.40124142, 0.44436589, 0.82561087, 0.27731523, 0.533465  ,
#        0.11606329, 0.43625363, 0.33904557, 0.77391425, 0.31111273,
#        0.89221603, 0.1242079 , 0.12445635, 0.47094697, 0.69735614,
#        0.77034159, 0.47511835, 0.17968349, 0.68488804, 0.6002454 ,
#        0.7298754 , 0.81544226, 0.55496387, 0.87961761, 0.65799326,
#        0.68779186, 0.33860746, 0.59654551, 0.48802036, 0.58124037,
#        0.31624094, 0.37975183, 0.77117012, 0.21495642, 0.53247863,
#        0.3536343 , 0.17715902, 0.25460453, 0.43899722, 0.14776813,
#        0.6288316 , 0.63248274, 0.67886902, 0.652702  , 0.7201403 ,
#        0.11034414, 0.12049701, 0.69668891, 0.60563482, 0.42764551,
#        0.46965196, 0.154356  , 0.6196269 , 0.85978316, 0.45341666,
#        0.21623836, 0.11296505, 0.17004533, 0.11865962, 0.73900015,
#        0.8761945 , 0.50528367, 0.78540419, 0.19778405, 0.42877915,
#        0.52974648, 0.6020475 , 0.12732253, 0.19271639, 0.53871483])

# %%
norma
# Out:
# array([107.49525396, 105.52376008, 131.16713808, 130.02108165,
#        107.96503358, 103.4653302 , 178.82310386, 114.25657881,
#        168.6763969 , 102.36510191, 103.19109837, 211.06765126,
#        112.17711637, 133.98675169, 129.64232316, 189.08337539,
#        191.16157744, 104.65020759, 163.85616867, 105.87377903,
#        236.57373244, 159.72850337, 151.52270997, 164.3568401 ,
#        122.3535594 , 125.23097543, 175.27237016, 110.1053371 ,
#        111.85390682, 181.21655747, 103.05415188, 101.88901498,
#        210.70780655, 126.21054776, 111.88705757, 181.94953926,
#        101.79816668, 111.47766541, 189.68635901, 117.47779619,
#        238.74974219, 178.77252681, 178.67602878, 103.18880278,
#        160.33980202, 188.26399567, 103.52972942, 157.92981339,
#        155.83268096, 128.23865304, 172.48849668, 206.51369386,
#        116.47052838, 233.37848093, 146.44560369, 156.87419122,
#        111.56221055, 127.18292298, 104.81209171, 122.9836452 ,
#        116.28717982, 105.11521336, 188.59346286, 145.58328934,
#        111.69442764, 108.84991507, 158.84371977, 132.8369626 ,
#        101.81274962, 169.73887807, 136.87464014, 138.0339668 ,
#        153.69038641, 144.65854091, 168.79660695, 184.19574792,
#        180.21680438, 160.09632515, 129.80324765, 101.8595641 ,
#        103.09039881, 167.25819886, 134.00601102, 224.98155415,
#        102.16018783, 145.15084281, 183.16484882, 161.43860871,
#        180.93394017, 175.98778739, 231.92396693, 107.04830951,
#        194.28963975, 151.49074953, 101.84219165, 111.16931811,
#        128.75832844, 177.56461332, 153.27266598, 112.93915562])

# %%
datos = np.column_stack([norma, pendientes])
datos
# Out:
# array([[1.07495254e+02, 5.08283179e-01],
#        [1.05523760e+02, 4.94024880e-01],
#        [1.31167138e+02, 2.60155608e-01],
#        [1.30021082e+02, 6.06376797e-01],
#        [1.07965034e+02, 3.59082956e-01],
#        [1.03465330e+02, 3.96040811e-01],
#        [1.78823104e+02, 1.24077710e-01],
#        [1.14256579e+02, 5.44998700e-01],
#        [1.68676397e+02, 7.19821327e-01],
#        [1.02365102e+02, 4.57993671e-01],
#        [1.03191098e+02, 3.99427604e-01],
#        [2.11067651e+02, 8.26480376e-01],
#        [1.12177116e+02, 3.35469259e-01],
#        [1.33986752e+02, 2.50840017e-01],
#        [1.29642323e+02, 2.65318832e-01],
#        [1.89083375e+02, 7.72401029e-01],
#        [1.91161577e+02, 7.77608249e-01],
#        [1.04650208e+02, 4.86562744e-01],
#        [1.63856169e+02, 7.06918764e-01],
#        [1.05873779e+02, 4.96777108e-01],
#        [2.36573732e+02, 8.87120018e-01],
#        [1.59728503e+02, 6.95679610e-01],
#        [1.51522710e+02, 1.97692730e-01],
#        [1.64356840e+02, 7.08269577e-01],
#        [1.22353559e+02, 2.91553585e-01],
#        [1.25230975e+02, 2.80847835e-01],
#        [1.75272370e+02, 1.33261956e-01],
#        [1.10105337e+02, 3.46408510e-01],
#        [1.11853907e+02, 5.33295833e-01],
#        [1.81216557e+02, 7.52467791e-01],
#        [1.03054152e+02, 4.01241423e-01],
#        [1.01889015e+02, 4.44365888e-01],
#        [2.10707807e+02, 8.25610866e-01],
#        [1.26210548e+02, 2.77315234e-01],
#        [1.11887058e+02, 5.33464996e-01],
#        [1.81949539e+02, 1.16063285e-01],
#        [1.01798167e+02, 4.36253629e-01],
#        [1.11477665e+02, 3.39045574e-01],
#        [1.89686359e+02, 7.73914251e-01],
#        [1.17477796e+02, 3.11112733e-01],
#        [2.38749742e+02, 8.92216026e-01],
#        [1.78772527e+02, 1.24207902e-01],
#        [1.78676029e+02, 1.24456349e-01],
#        [1.03188803e+02, 4.70946974e-01],
#        [1.60339802e+02, 6.97356142e-01],
#        [1.88263996e+02, 7.70341586e-01],
#        [1.03529729e+02, 4.75118348e-01],
#        [1.57929813e+02, 1.79683488e-01],
#        [1.55832681e+02, 6.84888038e-01],
#        [1.28238653e+02, 6.00245403e-01],
#        [1.72488497e+02, 7.29875399e-01],
#        [2.06513694e+02, 8.15442258e-01],
#        [1.16470528e+02, 5.54963867e-01],
#        [2.33378481e+02, 8.79617614e-01],
#        [1.46445604e+02, 6.57993264e-01],
#        [1.56874191e+02, 6.87791861e-01],
#        [1.11562211e+02, 3.38607461e-01],
#        [1.27182923e+02, 5.96545509e-01],
#        [1.04812092e+02, 4.88020356e-01],
#        [1.22983645e+02, 5.81240371e-01],
#        [1.16287180e+02, 3.16240945e-01],
#        [1.05115213e+02, 3.79751832e-01],
#        [1.88593463e+02, 7.71170116e-01],
#        [1.45583289e+02, 2.14956418e-01],
#        [1.11694428e+02, 5.32478633e-01],
#        [1.08849915e+02, 3.53634296e-01],
#        [1.58843720e+02, 1.77159024e-01],
#        [1.32836963e+02, 2.54604532e-01],
#        [1.01812750e+02, 4.38997221e-01],
#        [1.69738878e+02, 1.47768125e-01],
#        [1.36874640e+02, 6.28831599e-01],
#        [1.38033967e+02, 6.32482740e-01],
#        [1.53690386e+02, 6.78869017e-01],
#        [1.44658541e+02, 6.52701998e-01],
#        [1.68796607e+02, 7.20140300e-01],
#        [1.84195748e+02, 1.10344140e-01],
#        [1.80216804e+02, 1.20497014e-01],
#        [1.60096325e+02, 6.96688909e-01],
#        [1.29803248e+02, 6.05634821e-01],
#        [1.01859564e+02, 4.27645512e-01],
#        [1.03090399e+02, 4.69651958e-01],
#        [1.67258199e+02, 1.54356003e-01],
#        [1.34006011e+02, 6.19626902e-01],
#        [2.24981554e+02, 8.59783156e-01],
#        [1.02160188e+02, 4.53416663e-01],
#        [1.45150843e+02, 2.16238359e-01],
#        [1.83164849e+02, 1.12965049e-01],
#        [1.61438609e+02, 1.70045326e-01],
#        [1.80933940e+02, 1.18659624e-01],
#        [1.75987787e+02, 7.39000154e-01],
#        [2.31923967e+02, 8.76194502e-01],
#        [1.07048310e+02, 5.05283666e-01],
#        [1.94289640e+02, 7.85404189e-01],
#        [1.51490750e+02, 1.97784048e-01],
#        [1.01842192e+02, 4.28779146e-01],
#        [1.11169318e+02, 5.29746482e-01],
#        [1.28758328e+02, 6.02047504e-01],
#        [1.77564613e+02, 1.27322529e-01],
#        [1.53272666e+02, 1.92716391e-01],
#        [1.12939156e+02, 5.38714833e-01]])

# %%
np.savetxt('/content/exports/norma_pendientes.csv', datos, delimiter=',')
