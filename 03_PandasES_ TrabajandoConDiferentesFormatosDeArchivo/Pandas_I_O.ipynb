# %% [markdown]
# <a href="https://colab.research.google.com/github/RubenAndreeB/AluraCourse/blob/main/03_PandasES_%20TrabajandoConDiferentesFormatosDeArchivo/Pandas_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas E/S: trabajando con diferentes formatos de archivo

# %% [markdown]
# ## 1. Leyendo archivos CSV

# %% [markdown]
# ### Importando archivos CSV

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2723682196.py in <cell line: 0>()
# ----> 1 datos = pd.read_csv('superstore_data.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ### Parametros de la funcion read_csv
# Documentacion: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv', sep=';')

# %%
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows= 5)
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=['Id', 'Year_Birth', 'Income'])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols=[0, 1, 4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### Escribiendo archivos CSV
# Documentacion: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
datos_seleccion.to_csv('datos_mercado.csv', index=False)

# %%
datos_mercado = pd.read_csv('datos_mercado.csv')
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### Desafio: leyendo datos con múltiples parámetros
# Disponemos de un archivo en formato CSV (se encuentra en la carpeta Challenge), el cual se obtuvo de la página [Información de Salud (TABNET) - DATASUS](https://datasus.saude.gov.br/informacoes-de-saude-tabnet/). Este archivo contiene los gastos hospitalarios públicos de cada una de las Unidades de la Federación Brasileña desde enero de 2008 hasta marzo de 2021.
#
# Su **desafío** aquí será leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:
#
# 1. Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# 2. La codificación del archivo es ISO-8859-1.
# 3. Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# 4. Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# 5. Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'.

# %%
# 1: Separador por punto y coma
challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';')
challenge_1.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-2624582871.py in <cell line: 0>()
#       1 # 1: Separador por punto y coma
# ----> 2 challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';')
#       3 challenge_1.head()
#
# ...

# %% [markdown]
# Encontramos errores en la codificacion

# %%
# 2. Codificacion, ya sabiamos cual era, pero queria hacerlo yo
import chardet
with open('Challenge/datos_sus.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';', encoding='ISO-8859-1')
challenge_1.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-3112298014.py in <cell line: 0>()
# ----> 1 challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';', encoding='ISO-8859-1')
#       2 challenge_1.head()
#
# ...

# %%
# Nos encontramos con un error, por las primeras lineas ignorables
# 3. Saltar tres lineas
challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';', encoding='ISO-8859-1', skiprows=4)
challenge_1.head()
# Out:
#    Rondônia   1388528,39   2931283,42   1541682,52   1525314,96   1645953,84  \
# 0      Acre    902416,00   1497206,26   1794028,48   1730469,42   1819443,92
# 1  Amazonas   4735529,42   7118990,57   8196635,49   8259378,42   7831399,90
# 2   Roraima    657889,53    777939,31    718688,03    839994,39    862347,96
# 3      Pará  18864744,11  19553758,20  21937342,70  20842829,69  23249952,88
# 4     Amapá   1120973,34   1268740,33    974651,24   1141137,32    866346,18
#
#     1406150,68   3065279,01   3231494,61   3117178,63  ...  11824687,13  \
# 0   1828496,00   2511754,59   2089107,14   2275708,53  ...   3915193,20
# 1   8477273,62   9368858,72   9352532,70   9363099,35  ...  19769460,14
# 2    832440,66    996693,09    894271,18    910424,17  ...   3015488,30
# 3  23240687,56  24002223,56  23341218,03  25172261,32  ...  40804126,43
# 4   1440978,95   1426659,48   1475551,38   1651341,43  ...   3253399,45
#
#    11733307,76  10201985,14   7955139,45   9357946,29   8880836,55  \
# ...

# %%
# 4. Ignoraremos las ultimas lineas
# Debemos conocer cuanto es el tamanio
challenge_1 = pd.read_csv('Challenge/datos_sus.csv', sep=';', encoding='ISO-8859-1', skiprows=3, skipfooter=9, engine='python')
challenge_1
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ## 2. Leyendo archivos de excel

# %% [markdown]
# ### Importando archivos de excel

# %%
archivo = '/content/Aula2_excel/emisiones_CO2.xlsx'

# %%
datos_co2 = pd.read_excel(archivo)

# %%
datos_co2.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# ### Parametros de la funcion `read_excel`
# Documentacion: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')

# %%
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
percapita.sample(5)
# Out:
#           País ISO 3166-1 alpha-3   Año     Total    Carbón    Aceite  Gas  \
# 40828  Noruega                NOR  1778       NaN       NaN       NaN  NaN
# 35907  Mayotte                MYT  1753       NaN       NaN       NaN  NaN
# 15227  Dilandi                DJI  2017  376607.0       0.0  317006.0  0.0
# 31257   Lesoto                LSO  1999  914970.0  727566.0  187403.0  0.0
# 20457    Gabón                GAB  1807       NaN       NaN       NaN  NaN
#
#        Cemento  Quema  Otros
# 40828      NaN    NaN    NaN
# 35907      NaN    NaN    NaN
# 15227  59601.0    0.0    NaN
# 31257      0.0    0.0    NaN
# 20457      NaN    NaN    NaN

# %%
fuentes = pd.read_excel(archivo, sheet_name='fuentes')

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %%
# Generamos intervalos
intervalos = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D')

# %%
intervalos
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalos_2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols='A:D', nrows= 10)

# %%
intervalos_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ### Escribiendo archivos Excel

# %%
intervalos.to_excel('/content/Exports/co2_intervalos.xlsx', index=False)

# %%
pd.read_excel('/content/Exports/co2_intervalos.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ### Leyendo datos de Google Sheets

# %%
sheet_id = '1vfe1EZE96-vUlQ18dm7qyIijzz0vQNvuBGZ2XUlT-_0'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&gid=0'

# %%
datos_co2_sheets = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-2660740120.py in <cell line: 0>()
# ----> 1 datos_co2_sheets = pd.read_csv(url)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...
